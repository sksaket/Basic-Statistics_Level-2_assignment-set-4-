# %% [markdown]
# <a href="https://colab.research.google.com/github/sksaket/Basic-Statistics_Level-2_assignment-set-4-Q3/blob/main/assignment_set_4_Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
# For No investigation P(45<X<55)
# For Investigation 1-P(45<X<55)

# %%
# find z-scores at x=45; z=(s_mean-P_mean)/(p_SD/sqrt(n))
z=(45-50)/(40/100**0.5)
z
# Out:
# -1.25

# %%
# find z-scores at x=55; z=(s_mean-P_mean)/(p_SD/sqrt(n))
z=(55-50)/(40/100**0.5)
z
# Out:
# 1.25

# %%
# For No investigation P(45<X<55) using z_scores = P(X<50)-P(X<45)
stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
# Out:
# 0.7887004526662893

# %%
stats.norm.interval(0.7887,loc=50,scale=40/(100**0.5))
# Out:
# (45.00000495667348, 54.99999504332652)

# %%
# For Investigation 1-P(45<X<55)
1-0.7887
# Out:
# 0.21130000000000004
